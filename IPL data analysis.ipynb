# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
#df1 is the datset of ball to ball
df1=pd.read_csv('IPL_Ball_by_Ball.csv')
#df2 is the dataset of ipl matvhes played
df2=pd.read_csv('IPLMatches.csv')

# %%
df1
# Out:
#          id  inning  over  ball           batsman       non_striker  \
# 0    336010       1     8     6         DJ Hussey           T Taibu
# 1    336020       1    15     2         G Gambhir          S Dhawan
# 2    392217       2    16     6         ML Hayden       S Badrinath
# 3    392218       2    13     2  RE van der Merwe        MV Boucher
# 4    392222       1    17     6            K Goel         PP Chawla
# 5    392228       2    17     1         A Symonds         RG Sharma
# 6    419114       2     8     5        KD Karthik       MF Maharoof
# 7    419153       1     4     1         DJ Hussey         MK Tiwary
# 8    419159       2     4     1           M Vijay          SK Raina
# 9    419162       2     6     2      KP Pietersen          R Dravid
# 10   501201       1    16     4          UT Yadav  RE van der Merwe
# 11   501219       2    16     6         MK Tiwary          R Bhatia
# 12   501251       2     3     6         RG Sharma       AC Blizzard
# ...

# %%
df2
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # Datapreprocessing DF1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                37 non-null     int64
#  1   inning            37 non-null     int64
#  2   over              37 non-null     int64
#  3   ball              37 non-null     int64
#  4   batsman           37 non-null     object
#  5   non_striker       37 non-null     object
#  6   bowler            37 non-null     object
#  7   batsman_runs      37 non-null     int64
#  8   extra_runs        37 non-null     int64
#  9   total_runs        37 non-null     int64
#  10  non_boundary      37 non-null     int64
#  11  is_wicket         37 non-null     int64
#  12  dismissal_kind    37 non-null     object
#  13  player_dismissed  37 non-null     object
#  14  fielder           37 non-null     object
#  15  extras_type       37 non-null     object
# ...

# %%
df1.describe()
# Out:
#                  id     inning       over       ball  batsman_runs  \
# count  3.700000e+01  37.000000  37.000000  37.000000     37.000000
# mean   7.438477e+05   1.540541  11.216216   4.027027      0.027027
# std    2.885847e+05   0.505228   6.191998   1.907390      0.164399
# min    3.360100e+05   1.000000   0.000000   1.000000      0.000000
# 25%    4.191620e+05   1.000000   7.000000   2.000000      0.000000
# 50%    7.340310e+05   2.000000   9.000000   5.000000      0.000000
# 75%    9.809890e+05   2.000000  17.000000   6.000000      0.000000
# max    1.181766e+06   2.000000  19.000000   7.000000      1.000000
#
#        extra_runs  total_runs  non_boundary  is_wicket
# count        37.0   37.000000          37.0       37.0
# mean          1.0    1.027027           0.0        1.0
# std           0.0    0.164399           0.0        0.0
# min           1.0    1.000000           0.0        1.0
# 25%           1.0    1.000000           0.0        1.0
# ...

# %%
df1=df1.dropna()

# %%
df1.isnull().sum()
# Out:
# id                  0
# inning              0
# over                0
# ball                0
# batsman             0
# non_striker         0
# bowler              0
# batsman_runs        0
# extra_runs          0
# total_runs          0
# non_boundary        0
# is_wicket           0
# dismissal_kind      0
# player_dismissed    0
# fielder             0
# extras_type         0
# batting_team        0
# bowling_team        0
# dtype: int64

# %%
len(df1['batsman'])
# Out:
# 37

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                37 non-null     int64
#  1   inning            37 non-null     int64
#  2   over              37 non-null     int64
#  3   ball              37 non-null     int64
#  4   batsman           37 non-null     object
#  5   non_striker       37 non-null     object
#  6   bowler            37 non-null     object
#  7   batsman_runs      37 non-null     int64
#  8   extra_runs        37 non-null     int64
#  9   total_runs        37 non-null     int64
#  10  non_boundary      37 non-null     int64
#  11  is_wicket         37 non-null     int64
#  12  dismissal_kind    37 non-null     object
#  13  player_dismissed  37 non-null     object
#  14  fielder           37 non-null     object
#  15  extras_type       37 non-null     object
# ...

# %%
df1.isnull().sum()
# Out:
# id                  0
# inning              0
# over                0
# ball                0
# batsman             0
# non_striker         0
# bowler              0
# batsman_runs        0
# extra_runs          0
# total_runs          0
# non_boundary        0
# is_wicket           0
# dismissal_kind      0
# player_dismissed    0
# fielder             0
# extras_type         0
# batting_team        0
# bowling_team        0
# dtype: int64

# %% [markdown]
# # Data Preprocessing dataset2

# %%
df2
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df2.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
player_of_match=[]
for i in df2['player_of_match']:
    player_of_match.append(i)
imputer=SimpleImputer(missing_values = np.nan,strategy='most_frequent')
player_of_match=np.reshape(df2['player_of_match'].values,(816,1))
imputer.fit(player_of_match)
player_of_match=imputer.transform(player_of_match)
df2['player_of_match']=player_of_match

# %%
city=[]
for i in df2['city']:
    city.append(i)
imputer=SimpleImputer(missing_values = np.nan,strategy='most_frequent')
city=np.reshape(df2['city'].values,(816,1))
imputer.fit(city)
city=imputer.transform(city)
df2['city']=city

# %%
result_margin=[]
for i in df2['result_margin']:
    result_margin.append(i)
imputer=SimpleImputer(missing_values = np.nan,strategy='most_frequent')
result_margin=np.reshape(df2['result_margin'].values,(816,1))
imputer.fit(result_margin)
result_margin=imputer.transform(result_margin)
df2['result_margin']=result_margin

# %%
winner=[]
for i in df2['winner']:
    winner.append(i)
imputer=SimpleImputer(missing_values = np.nan,strategy='most_frequent')
winner=np.reshape(df2['winner'].values,(816,1))
imputer.fit(winner)
winner=imputer.transform(winner)
df2['winner']=winner

# %%
result=[]
for i in df2['result']:
    result.append(i)
imputer=SimpleImputer(missing_values = np.nan,strategy='most_frequent')
result=np.reshape(df2['result'].values,(816,1))
imputer.fit(result)
result=imputer.transform(result)
df2['result']=result

# %%
eliminator=[]
for i in df2['eliminator']:
    eliminator.append(i)
imputer=SimpleImputer(missing_values = np.nan,strategy='most_frequent')
eliminator=np.reshape(df2['eliminator'].values,(816,1))
imputer.fit(eliminator)
eliminator=imputer.transform(eliminator)
df2['eliminator']=eliminator

# %%
method=[]
for i in df2['method']:
    method.append(i)
imputer=SimpleImputer(missing_values = np.nan,strategy='most_frequent')
method=np.reshape(df2['method'].values,(816,1))
imputer.fit(method)
method=imputer.transform(method)
df2['method']=method

# %%
df2.isnull().sum()
# Out:
# id                 0
# city               0
# date               0
# player_of_match    0
# venue              0
# neutral_venue      0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# eliminator         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %% [markdown]
# # how many matches played in each season

# %%
#length of the dataset2 is 816
#length of dataset1 is 37

# %%
datelst=[]
for i in df2['date']:
    datelst.append(i)
Year=[]    
for i in datelst:
    Year.append(i[:4])  
# Convert the list to a DataFrame
year_= pd.DataFrame(Year, columns=['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
y2008=['2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008']

y2009=[ '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009']
print('matches played in 2009 is :',len(y2009))
y2010=['2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010', '2010']
print('matches played in 2010 is :',len(y2010))
y2011=[ '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011']
print('matches played in 2011 is :',len(y2011))
y2012=[ '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012']
print('matches played in 2012 is :',len(y2012))
y2013=['2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013']
print('matches played in 2013 is :',len(y2013))
y2014=['2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014']
print('matches played in 2014 is :',len(y2014))
y2015=['2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015']
print('matches played in 2015 is :',len(y2015))
y2016=['2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016']
print('matches played in 2016 is :',len(y2016))
y2017=['2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017']
print('matches played in 2017 is :',len(y2017))
y2018=['2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018']
print('matches played in 2018 is :',len(y2018))
y2019=['2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019']
print('matches played in 2019 is :',len(y2019))
y2020=['2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020']
print('matches played in 2020 is :',len(y2020))
# Out:
# matches played in 2009 is : 57
# matches played in 2010 is : 60
# matches played in 2011 is : 73
# matches played in 2012 is : 74
# matches played in 2013 is : 76
# matches played in 2014 is : 60
# matches played in 2015 is : 59
# matches played in 2016 is : 60
# matches played in 2017 is : 59
# matches played in 2018 is : 60
# matches played in 2019 is : 60
# matches played in 2020 is : 60

# %% [markdown]
# # runs scored in each season

# %%
df1
# Out:
#          id  inning  over  ball           batsman       non_striker  \
# 0    336010       1     8     6         DJ Hussey           T Taibu
# 1    336020       1    15     2         G Gambhir          S Dhawan
# 2    392217       2    16     6         ML Hayden       S Badrinath
# 3    392218       2    13     2  RE van der Merwe        MV Boucher
# 4    392222       1    17     6            K Goel         PP Chawla
# 5    392228       2    17     1         A Symonds         RG Sharma
# 6    419114       2     8     5        KD Karthik       MF Maharoof
# 7    419153       1     4     1         DJ Hussey         MK Tiwary
# 8    419159       2     4     1           M Vijay          SK Raina
# 9    419162       2     6     2      KP Pietersen          R Dravid
# 10   501201       1    16     4          UT Yadav  RE van der Merwe
# 11   501219       2    16     6         MK Tiwary          R Bhatia
# 12   501251       2     3     6         RG Sharma       AC Blizzard
# ...

# %%
df2
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df1['id'].values
# Out:
# array([ 336010,  336020,  392217,  392218,  392222,  392228,  419114,
#         419153,  419159,  419162,  501201,  501219,  501251,  548375,
#         598012,  733979,  733989,  733995,  734031,  829707,  829713,
#         829769,  829775,  829803,  829821,  980917,  980969,  980989,
#        1082592, 1082617, 1082625, 1082639, 1136573, 1136574, 1136600,
#        1175360, 1181766], dtype=int64)

# %%
L_=[]
for i in df2.values:
    if(i[0])
# Out:
#   Cell In[508], line 3
#     if(i[0])
#             ^
# SyntaxError: expected ':'
